# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(1000)
y=np.random.standard_normal(20)
x=range(len(y))
plt.plot(x,y)

# %%
plt.plot(y)

# %%
plt.plot(y.cumsum(),'b',lw=1.5)
plt.plot(y.cumsum(),'rp')
plt.grid(True)
plt.axis('tight')
plt.xlim(-1,20)
plt.ylim(np.min(y.cumsum())-1,np.max(y.cumsum())+1)
plt.title('Random chart')
plt.ylabel('value')
plt.xlabel('index')

# %%
y=np.random.standard_normal((20,2)).cumsum(axis=0)
plt.figure(figsize=(7,4))
plt.plot(y,lw=1.5)
plt.plot(y,'ro')
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')
ply.ylabel('value')
plt.title('a Plot')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ff0939f98593> in <module>()
#       6 plt.axis('tight')
#       7 plt.xlabel('index')
# ----> 8 ply.ylabel('value')
#       9 plt.title('a Plot')
#
# NameError: name 'ply' is not defined

# %%
y[:,0]=y[:,0]*100
plt.figure(figsize=(7,4))
plt.plot(y[:,0],lw=1.5,label='1st')
plt.plot(y[:,1],lw=1.5,label='2nd')
plt.plot(y,'ro')
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('a Plot')

# %%
plt.figure(figsize=(7,4))
plt.subplot(211)
plt.plot(y[:,0],lw=1.5,label='1st')
plt.plot(y[:,0],'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.subplot(212)
plt.plot(y[:,1],'g',lw=1.5,label='1st')
plt.plot(y[:,1],'ro')
plt.grid(True)
plt.legend(loc=0)

# %%
plt.figure(figsize=(7,4))
plt.subplot(121)
plt.plot(y[:,0],lw=1.5,label='1st')
plt.plot(y[:,0],'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.subplot(122)
plt.bar(np.arange(len(y)),y[:,1],width=0.5,color='g',label='2nd')
plt.grid(True)
plt.legend(loc=0)

# %%
plt.figure(figsize=(7,5))
plt.scatter(y[:,0],y[:,1],marker='o')
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter plot')

# %%
c=np.random.randint(0,10,len(y))
plt.figure(figsize=(7,5))
plt.scatter(y[:,0],y[:,1],c=c,marker='o')
plt.colorbar()
plt.grid(True)
plt.title('Scatter with a bar')

# %%
plt.figure(figsize=(7,4))
plt.hist(y,label=['1st','2nd'],bins=25)
plt.grid(True)
plt.legend(loc=0)
plt.title('Histogram')

# %%
import matplotlib.finance as mpf
start=(2014,1,1)
end=(2015,1,1)
quotes = mpf.quotes_historical_yahoo('^GDAXI',start,end)
# Out:
# /Users/marcinwalendzik/anaconda/lib/python2.7/site-packages/matplotlib/finance.py:485: MatplotlibDeprecationWarning: This function has been deprecated in 1.4 in favor of `quotes_historical_yahoo_ochl`, which maintains the original argument order, or `quotes_historical_yahoo_ohlc`, which uses the open-high-low-close order. This function will be removed in 1.5
#   mplDeprecation)

# %%
quotes[:2]
# Out:
# [(735235.0,
#   9598.25,
#   9400.0400000000009,
#   9620.9300000000003,
#   9394.2099999999991,
#   90956900.0),
#  (735236.0,
#   9409.6599999999999,
#   9435.1499999999996,
#   9453.4799999999996,
#   9367.9899999999998,
#   58772900.0)]

# %%
fig,ax = plt.subplots(figsize=(8,5))
fig.subplots_adjust(bottom=0.2)
mpf.candlestick(ax,quotes,width=0.6,colorup='b',colordown='r')
plt.grid(True)
ax.xaxis_date()
ax.autoscale_view()
plt.setp(plt.gca().get_xticklabels(),rotation=30)
ax.autoscale_view()

# %%
quotes=np.array(mpf.quotes_historical_yahoo('YHOO',start,end))
fig,(ax1,ax2) = plt.subplots(2,sharex=True,figsize=(8,6))
mpf.candlestick(ax1,quotes,width=0.5,colorup='b',colordown='r')
ax1.set_title('Yahoo')
ax1.grid(True)
ax1.set_ylabel('Index')
ax1.xaxis_date()
plt.bar(quotes[:,0]-0.25,quotes[:,5],width=0.5)
ax2.set_ylabel('volume')
ax2.grid(True)
ax2.autoscale_view()
ax2.set_title('Volume of Yahoo')
